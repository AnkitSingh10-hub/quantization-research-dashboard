# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import os

RESULTS_DIR = "/content/drive/MyDrive/ExperimentalProjects/Quantization/results"

files = [
    "fp16_results.csv",
    # "int8_results.csv",
    # "int4_results.csv",
    # "nf4_results.csv",
]

results = pd.concat(
    [pd.read_csv(os.path.join(RESULTS_DIR, f)) for f in files],
    ignore_index=True
)

results
# Out:
#   Precision  VRAM (GB)  Latency (s)  Tokens/s  Perplexity  Accuracy (%)
# 0      FP16   6.434032     1.008188  13.76348   17.052198     76.767677
